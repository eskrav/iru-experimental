# %%
import pandas as pn
import regex as re
import csv
import os
import statistics as s
import numpy as np

# %%
i = 1
files = []

while os.path.exists(f"/Users/ekravtch/Shared/informationally-redundant-utterances/data/MTurk/fillers_{i}.csv"):
    files.append(pn.read_csv(f"/Users/ekravtch/Shared/informationally-redundant-utterances/data/MTurk/fillers_{i}.csv"))
    i += 1
data = pn.concat(files)

# %%
data = data.rename(columns={"WorkerId":"id","SecondsOnHIT":"time"}) 
cols = ["id","time","trials","demographics"]
data = data[cols]
data = data.replace({'\[{':'','{':'','}\]':''}, regex=True)
data
# Out:
#                id  time                                             trials  \
# 0  A3F2J0WFJKEHQ6   433  "story":"23_library","prag_condition":"3_fille...
# 1   ATF7HBD1TFI2U   743  "story":"20_drive","prag_condition":"e_typical...
# 2  A1JN13098RIE78   902  "story":"1_grocery","prag_condition":"2_filler...
# 3  A29ANBEU3JKCKZ   565  "story":"3_feed_dog","prag_condition":"4_fille...
# 4  A1RVMADIZE3BXK  1233  "story":"21_pizza","prag_condition":"b_typical...
#
#                                         demographics
# 0  "gender":"male","age":"55","language":"English...
# 1  "gender":"female","age":"45","language":"engli...
# 2  "gender":"female","age":"55","language":"Engli...
# 3  "gender":"female","age":"25","language":"Engli...
# 4  "gender":"female","age":"35","language":"Engli...

# %%
print(f'Average: {round(s.mean(data["time"])/60,2)} minutes')
# Out:
# Average: 12.92 minutes

# %%
data["trials"][0]
# Out:
# '"story":"23_library","prag_condition":"3_filler","experiment":"period","marker1":"","marker2":".&quot;","redundantQ":"4.47","informativeQ":"49.48","distractorQ1":"77.96","distractorQ2":"49.48","rt":37905},"story":"18_hair","prag_condition":"a_typical_redundant","experiment":"period","marker1":"","marker2":".&quot;","redundantQ":"92.69","informativeQ":"52.92","distractorQ1":"90.48","distractorQ2":"12.49","rt":25457},"story":"2_restaurant","prag_condition":"c_biased_redundant","experiment":"control","marker1":"You wouldn\'t have expected it, but ","marker2":".&quot;","redundantQ":"48.74","informativeQ":"49.15","distractorQ1":"84.59","distractorQ2":"28.20","rt":32099},"story":"17_airplane","prag_condition":"2_filler","experiment":"ohyeah","marker1":"Oh yeah, and ","marker2":".&quot;","redundantQ":"85.89","informativeQ":"75.58","distractorQ1":"79.76","distractorQ2":"29.68","rt":37324},"story":"1_grocery","prag_condition":"d_biased_informative","experiment":"ohyeah","marker1":"Oh yeah, and ","marker2":".&quot;","redundantQ":"17.40","informativeQ":"46.37","distractorQ1":"31.88","distractorQ2":"81.80","rt":36312},"story":"13_bus","prag_condition":"f_informative","experiment":"exclamation","marker1":"","marker2":"!&quot;","redundantQ":"1.61","informativeQ":"49.07","distractorQ1":"87.70","distractorQ2":"20.76","rt":24275},"story":"8_work","prag_condition":"e_typical","experiment":"exclamation","marker1":"","marker2":"!&quot;","redundantQ":"53.00","informativeQ":"30.90","distractorQ1":"98.33","distractorQ2":"10.20","rt":31269},"story":"7_train","prag_condition":"b_typical_informative","experiment":"exclamation","marker1":"","marker2":"!&quot;","redundantQ":"98.01","informativeQ":"29.59","distractorQ1":"86.39","distractorQ2":"81.97","rt":34153},"story":"4_subway","prag_condition":"1_filler","experiment":"exclamation","marker1":"","marker2":"!&quot;","redundantQ":"88.10","informativeQ":"9.46","distractorQ1":"94.57","distractorQ2":"28.61","rt":36620},"story":"5_fueling","prag_condition":"4_filler","experiment":"exclamation","marker1":"","marker2":"!&quot;","redundantQ":"50.22","informativeQ":"13.23","distractorQ1":"49.40","distractorQ2":"50.54","rt":25200'

# %%
s = data["trials"].str.split('},').apply(pn.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = "trials"
s
# Out:
# 0    "story":"23_library","prag_condition":"3_fille...
# 0    "story":"18_hair","prag_condition":"a_typical_...
# 0    "story":"2_restaurant","prag_condition":"c_bia...
# 0    "story":"17_airplane","prag_condition":"2_fill...
# 0    "story":"1_grocery","prag_condition":"d_biased...
# 0    "story":"13_bus","prag_condition":"f_informati...
# 0    "story":"8_work","prag_condition":"e_typical",...
# 0    "story":"7_train","prag_condition":"b_typical_...
# 0    "story":"4_subway","prag_condition":"1_filler"...
# 0    "story":"5_fueling","prag_condition":"4_filler...
# 1    "story":"20_drive","prag_condition":"e_typical...
# 1    "story":"17_airplane","prag_condition":"2_fill...
# 1    "story":"3_feed_dog","prag_condition":"d_biase...
# 1    "story":"12_letter","prag_condition":"4_filler...
# 1    "story":"7_train","prag_condition":"c_biased_r...
# 1    "story":"9_doctor","prag_condition":"3_filler"...
# 1    "story":"6_swimming","prag_condition":"b_typic...
# 1    "story":"10_shampoo","prag_condition":"f_infor...
# 1    "story":"5_fueling","prag_condition":"1_filler...
# 1    "story":"22_dishes","prag_condition":"a_typica...
# 2    "story":"1_grocery","prag_condition":"2_filler...
# 2    "story":"10_shampoo","prag_condition":"4_fille...
# 2    "story":"3_feed_dog","prag_condition":"d_biase...
# 2    "story":"12_letter","prag_condition":"1_filler...
# 2    "story":"11_skydiving","prag_condition":"b_typ...
# 2    "story":"23_library","prag_condition":"e_typic...
# 2    "story":"9_doctor","prag_condition":"3_filler"...
# 2    "story":"18_hair","prag_condition":"c_biased_r...
# 2    "story":"5_fueling","prag_condition":"f_inform...
# 2    "story":"2_restaurant","prag_condition":"a_typ...
# 3    "story":"3_feed_dog","prag_condition":"4_fille...
# 3    "story":"4_subway","prag_condition":"a_typical...
# 3    "story":"22_dishes","prag_condition":"1_filler...
# 3    "story":"20_drive","prag_condition":"e_typical...
# 3    "story":"13_bus","prag_condition":"3_filler","...
# 3    "story":"23_library","prag_condition":"b_typic...
# 3    "story":"17_airplane","prag_condition":"2_fill...
# 3    "story":"19_exhibit","prag_condition":"d_biase...
# 3    "story":"18_hair","prag_condition":"c_biased_r...
# 3    "story":"24_laundry","prag_condition":"f_infor...
# 4    "story":"21_pizza","prag_condition":"b_typical...
# 4    "story":"13_bus","prag_condition":"f_informati...
# 4    "story":"12_letter","prag_condition":"c_biased...
# 4    "story":"17_airplane","prag_condition":"d_bias...
# 4    "story":"10_shampoo","prag_condition":"e_typic...
# 4    "story":"19_exhibit","prag_condition":"4_fille...
# 4    "story":"6_swimming","prag_condition":"3_fille...
# 4    "story":"9_doctor","prag_condition":"a_typical...
# 4    "story":"1_grocery","prag_condition":"2_filler...
# 4    "story":"14_clothes","prag_condition":"1_fille...
# Name: trials, dtype: object

# %%
ratings = data[["id","time"]]

ratings = ratings.join(s.apply(lambda x: pn.Series(x.split('","'))))

ratings
# Out:
#                id  time                      0  \
# 0  A3F2J0WFJKEHQ6   433    "story":"23_library
# 0  A3F2J0WFJKEHQ6   433       "story":"18_hair
# 0  A3F2J0WFJKEHQ6   433  "story":"2_restaurant
# 0  A3F2J0WFJKEHQ6   433   "story":"17_airplane
# 0  A3F2J0WFJKEHQ6   433     "story":"1_grocery
# 0  A3F2J0WFJKEHQ6   433        "story":"13_bus
# 0  A3F2J0WFJKEHQ6   433        "story":"8_work
# 0  A3F2J0WFJKEHQ6   433       "story":"7_train
# 0  A3F2J0WFJKEHQ6   433      "story":"4_subway
# 0  A3F2J0WFJKEHQ6   433     "story":"5_fueling
# 1   ATF7HBD1TFI2U   743      "story":"20_drive
# 1   ATF7HBD1TFI2U   743   "story":"17_airplane
# 1   ATF7HBD1TFI2U   743    "story":"3_feed_dog
# 1   ATF7HBD1TFI2U   743     "story":"12_letter
# 1   ATF7HBD1TFI2U   743       "story":"7_train
# 1   ATF7HBD1TFI2U   743      "story":"9_doctor
# 1   ATF7HBD1TFI2U   743    "story":"6_swimming
# 1   ATF7HBD1TFI2U   743    "story":"10_shampoo
# 1   ATF7HBD1TFI2U   743     "story":"5_fueling
# 1   ATF7HBD1TFI2U   743     "story":"22_dishes
# 2  A1JN13098RIE78   902     "story":"1_grocery
# 2  A1JN13098RIE78   902    "story":"10_shampoo
# 2  A1JN13098RIE78   902    "story":"3_feed_dog
# 2  A1JN13098RIE78   902     "story":"12_letter
# 2  A1JN13098RIE78   902  "story":"11_skydiving
# 2  A1JN13098RIE78   902    "story":"23_library
# 2  A1JN13098RIE78   902      "story":"9_doctor
# 2  A1JN13098RIE78   902       "story":"18_hair
# 2  A1JN13098RIE78   902     "story":"5_fueling
# 2  A1JN13098RIE78   902  "story":"2_restaurant
# 3  A29ANBEU3JKCKZ   565    "story":"3_feed_dog
# 3  A29ANBEU3JKCKZ   565      "story":"4_subway
# 3  A29ANBEU3JKCKZ   565     "story":"22_dishes
# 3  A29ANBEU3JKCKZ   565      "story":"20_drive
# 3  A29ANBEU3JKCKZ   565        "story":"13_bus
# 3  A29ANBEU3JKCKZ   565    "story":"23_library
# 3  A29ANBEU3JKCKZ   565   "story":"17_airplane
# 3  A29ANBEU3JKCKZ   565    "story":"19_exhibit
# 3  A29ANBEU3JKCKZ   565       "story":"18_hair
# 3  A29ANBEU3JKCKZ   565    "story":"24_laundry
# 4  A1RVMADIZE3BXK  1233      "story":"21_pizza
# 4  A1RVMADIZE3BXK  1233        "story":"13_bus
# 4  A1RVMADIZE3BXK  1233     "story":"12_letter
# 4  A1RVMADIZE3BXK  1233   "story":"17_airplane
# 4  A1RVMADIZE3BXK  1233    "story":"10_shampoo
# 4  A1RVMADIZE3BXK  1233    "story":"19_exhibit
# 4  A1RVMADIZE3BXK  1233    "story":"6_swimming
# 4  A1RVMADIZE3BXK  1233      "story":"9_doctor
# 4  A1RVMADIZE3BXK  1233     "story":"1_grocery
# 4  A1RVMADIZE3BXK  1233    "story":"14_clothes
#
#                                         1                         2  \
# 0               prag_condition":"3_filler       experiment":"period
# 0    prag_condition":"a_typical_redundant       experiment":"period
# 0     prag_condition":"c_biased_redundant      experiment":"control
# 0               prag_condition":"2_filler       experiment":"ohyeah
# 0   prag_condition":"d_biased_informative       experiment":"ohyeah
# 0          prag_condition":"f_informative  experiment":"exclamation
# 0              prag_condition":"e_typical  experiment":"exclamation
# 0  prag_condition":"b_typical_informative  experiment":"exclamation
# 0               prag_condition":"1_filler  experiment":"exclamation
# 0               prag_condition":"4_filler  experiment":"exclamation
# 1              prag_condition":"e_typical  experiment":"exclamation
# 1               prag_condition":"2_filler  experiment":"exclamation
# 1   prag_condition":"d_biased_informative  experiment":"exclamation
# 1               prag_condition":"4_filler       experiment":"period
# 1     prag_condition":"c_biased_redundant       experiment":"period
# 1               prag_condition":"3_filler      experiment":"control
# 1  prag_condition":"b_typical_informative      experiment":"control
# 1          prag_condition":"f_informative       experiment":"ohyeah
# 1               prag_condition":"1_filler       experiment":"ohyeah
# 1    prag_condition":"a_typical_redundant       experiment":"ohyeah
# 2               prag_condition":"2_filler  experiment":"exclamation
# 2               prag_condition":"4_filler  experiment":"exclamation
# 2   prag_condition":"d_biased_informative  experiment":"exclamation
# 2               prag_condition":"1_filler      experiment":"control
# 2  prag_condition":"b_typical_informative      experiment":"control
# 2              prag_condition":"e_typical       experiment":"period
# 2               prag_condition":"3_filler       experiment":"period
# 2     prag_condition":"c_biased_redundant       experiment":"period
# 2          prag_condition":"f_informative       experiment":"ohyeah
# 2    prag_condition":"a_typical_redundant       experiment":"ohyeah
# 3               prag_condition":"4_filler       experiment":"period
# 3    prag_condition":"a_typical_redundant       experiment":"period
# 3               prag_condition":"1_filler  experiment":"exclamation
# 3              prag_condition":"e_typical  experiment":"exclamation
# 3               prag_condition":"3_filler  experiment":"exclamation
# 3  prag_condition":"b_typical_informative  experiment":"exclamation
# 3               prag_condition":"2_filler      experiment":"control
# 3   prag_condition":"d_biased_informative      experiment":"control
# 3     prag_condition":"c_biased_redundant       experiment":"ohyeah
# 3          prag_condition":"f_informative       experiment":"ohyeah
# 4  prag_condition":"b_typical_informative      experiment":"control
# 4          prag_condition":"f_informative       experiment":"ohyeah
# 4     prag_condition":"c_biased_redundant       experiment":"ohyeah
# 4   prag_condition":"d_biased_informative       experiment":"period
# 4              prag_condition":"e_typical  experiment":"exclamation
# 4               prag_condition":"4_filler  experiment":"exclamation
# 4               prag_condition":"3_filler  experiment":"exclamation
# 4    prag_condition":"a_typical_redundant  experiment":"exclamation
# 4               prag_condition":"2_filler  experiment":"exclamation
# 4               prag_condition":"1_filler  experiment":"exclamation
#
#                                                    3                  4  \
# 0                                         marker1":"  marker2":".&quot;
# 0                                         marker1":"  marker2":".&quot;
# 0      marker1":"You wouldn't have expected it, but   marker2":".&quot;
# 0                            marker1":"Oh yeah, and   marker2":".&quot;
# 0                            marker1":"Oh yeah, and   marker2":".&quot;
# 0                                         marker1":"  marker2":"!&quot;
# 0                                         marker1":"  marker2":"!&quot;
# 0                                         marker1":"  marker2":"!&quot;
# 0                                         marker1":"  marker2":"!&quot;
# 0                                         marker1":"  marker2":"!&quot;
# 1                                         marker1":"  marker2":"!&quot;
# 1                                         marker1":"  marker2":"!&quot;
# 1                                         marker1":"  marker2":"!&quot;
# 1                                         marker1":"  marker2":".&quot;
# 1                                         marker1":"  marker2":".&quot;
# 1  marker1":"You didn't think this would happen, ...  marker2":".&quot;
# 1  marker1":"You didn't think this would happen, ...  marker2":".&quot;
# 1                            marker1":"Oh yeah, and   marker2":".&quot;
# 1                            marker1":"Oh yeah, and   marker2":".&quot;
# 1                            marker1":"Oh yeah, and   marker2":".&quot;
# 2                                         marker1":"  marker2":"!&quot;
# 2                                         marker1":"  marker2":"!&quot;
# 2                                         marker1":"  marker2":"!&quot;
# 2            marker1":"You wouldn't believe it, but   marker2":".&quot;
# 2            marker1":"You wouldn't believe it, but   marker2":".&quot;
# 2                                         marker1":"  marker2":".&quot;
# 2                                         marker1":"  marker2":".&quot;
# 2                                         marker1":"  marker2":".&quot;
# 2                            marker1":"Oh yeah, and   marker2":".&quot;
# 2                            marker1":"Oh yeah, and   marker2":".&quot;
# 3                                         marker1":"  marker2":".&quot;
# 3                                         marker1":"  marker2":".&quot;
# 3                                         marker1":"  marker2":"!&quot;
# 3                                         marker1":"  marker2":"!&quot;
# 3                                         marker1":"  marker2":"!&quot;
# 3                                         marker1":"  marker2":"!&quot;
# 3                 marker1":"You'd be surprised, but   marker2":".&quot;
# 3                 marker1":"You'd be surprised, but   marker2":".&quot;
# 3                            marker1":"Oh yeah, and   marker2":".&quot;
# 3                            marker1":"Oh yeah, and   marker2":".&quot;
# 4  marker1":"You didn't think this would happen, ...  marker2":".&quot;
# 4                            marker1":"Oh yeah, and   marker2":".&quot;
# 4                            marker1":"Oh yeah, and   marker2":".&quot;
# 4                                         marker1":"  marker2":".&quot;
# 4                                         marker1":"  marker2":"!&quot;
# 4                                         marker1":"  marker2":"!&quot;
# 4                                         marker1":"  marker2":"!&quot;
# 4                                         marker1":"  marker2":"!&quot;
# 4                                         marker1":"  marker2":"!&quot;
# 4                                         marker1":"  marker2":"!&quot;
#
#                      5                     6                      7  \
# 0    redundantQ":"4.47  informativeQ":"49.48   distractorQ1":"77.96
# 0   redundantQ":"92.69  informativeQ":"52.92   distractorQ1":"90.48
# 0   redundantQ":"48.74  informativeQ":"49.15   distractorQ1":"84.59
# 0   redundantQ":"85.89  informativeQ":"75.58   distractorQ1":"79.76
# 0   redundantQ":"17.40  informativeQ":"46.37   distractorQ1":"31.88
# 0    redundantQ":"1.61  informativeQ":"49.07   distractorQ1":"87.70
# 0   redundantQ":"53.00  informativeQ":"30.90   distractorQ1":"98.33
# 0   redundantQ":"98.01  informativeQ":"29.59   distractorQ1":"86.39
# 0   redundantQ":"88.10   informativeQ":"9.46   distractorQ1":"94.57
# 0   redundantQ":"50.22  informativeQ":"13.23   distractorQ1":"49.40
# 1   redundantQ":"94.27   informativeQ":"2.22   distractorQ1":"98.61
# 1   redundantQ":"99.36  informativeQ":"47.56   distractorQ1":"78.37
# 1   redundantQ":"98.74   informativeQ":"4.08   distractorQ1":"77.74
# 1    redundantQ":"8.55   informativeQ":"0.10   distractorQ1":"51.04
# 1   redundantQ":"86.32  informativeQ":"48.92   distractorQ1":"97.74
# 1    redundantQ":"9.92  informativeQ":"47.19   distractorQ1":"15.14
# 1   redundantQ":"98.61   informativeQ":"7.43   distractorQ1":"48.80
# 1    redundantQ":"0.48  informativeQ":"48.55   distractorQ1":"49.55
# 1   redundantQ":"98.99   informativeQ":"0.35   distractorQ1":"48.92
# 1   redundantQ":"83.83   informativeQ":"3.83   distractorQ1":"98.86
# 2   redundantQ":"99.13  informativeQ":"50.72   distractorQ1":"49.07
# 2    redundantQ":"1.84  informativeQ":"48.60   distractorQ1":"71.45
# 2   redundantQ":"98.31  informativeQ":"50.84   distractorQ1":"89.59
# 2   redundantQ":"90.18  informativeQ":"52.37   distractorQ1":"73.34
# 2   redundantQ":"80.52  informativeQ":"32.58   distractorQ1":"48.01
# 2   redundantQ":"98.07  informativeQ":"57.20   distractorQ1":"81.94
# 2   redundantQ":"10.09   informativeQ":"2.67   distractorQ1":"29.05
# 2   redundantQ":"17.15  informativeQ":"49.78   distractorQ1":"60.97
# 2   redundantQ":"73.22  informativeQ":"24.81   distractorQ1":"62.15
# 2   redundantQ":"57.79  informativeQ":"25.04   distractorQ1":"62.74
# 3   redundantQ":"24.12  informativeQ":"38.32   distractorQ1":"90.20
# 3   redundantQ":"98.74  informativeQ":"50.13   distractorQ1":"99.50
# 3  redundantQ":"100.00  informativeQ":"33.17   distractorQ1":"94.35
# 3   redundantQ":"86.06  informativeQ":"49.50   distractorQ1":"98.74
# 3   redundantQ":"62.44  informativeQ":"67.09   distractorQ1":"94.22
# 3   redundantQ":"68.09  informativeQ":"86.93   distractorQ1":"48.24
# 3   redundantQ":"98.62  informativeQ":"69.72   distractorQ1":"92.59
# 3  redundantQ":"100.00  informativeQ":"49.75  distractorQ1":"100.00
# 3  redundantQ":"100.00  informativeQ":"99.37   distractorQ1":"86.68
# 3   redundantQ":"99.75  informativeQ":"98.62   distractorQ1":"77.01
# 4   redundantQ":"98.47  informativeQ":"10.65   distractorQ1":"26.26
# 4    redundantQ":"0.14  informativeQ":"66.63   distractorQ1":"83.70
# 4    redundantQ":"0.04   informativeQ":"6.17   distractorQ1":"82.03
# 4    redundantQ":"0.97  informativeQ":"24.18   distractorQ1":"90.98
# 4   redundantQ":"99.93  informativeQ":"51.86   distractorQ1":"97.95
# 4   redundantQ":"96.71  informativeQ":"63.51   distractorQ1":"78.29
# 4   redundantQ":"78.81  informativeQ":"11.59   distractorQ1":"80.06
# 4   redundantQ":"48.53  informativeQ":"29.07   distractorQ1":"28.34
# 4   redundantQ":"99.00  informativeQ":"49.26   distractorQ1":"86.88
# 4   redundantQ":"71.63  informativeQ":"73.19   distractorQ1":"84.43
#
#                       8           9
# 0  distractorQ2":"49.48   rt":37905
# 0  distractorQ2":"12.49   rt":25457
# 0  distractorQ2":"28.20   rt":32099
# 0  distractorQ2":"29.68   rt":37324
# 0  distractorQ2":"81.80   rt":36312
# 0  distractorQ2":"20.76   rt":24275
# 0  distractorQ2":"10.20   rt":31269
# 0  distractorQ2":"81.97   rt":34153
# 0  distractorQ2":"28.61   rt":36620
# 0  distractorQ2":"50.54   rt":25200
# 1  distractorQ2":"60.73   rt":43945
# 1  distractorQ2":"49.79   rt":52525
# 1  distractorQ2":"74.76   rt":78907
# 1  distractorQ2":"63.21   rt":52239
# 1  distractorQ2":"77.37   rt":48564
# 1  distractorQ2":"49.67   rt":57433
# 1  distractorQ2":"62.34   rt":52478
# 1  distractorQ2":"78.49   rt":53440
# 1  distractorQ2":"50.91   rt":36991
# 1  distractorQ2":"67.56   rt":44289
# 2  distractorQ2":"72.04   rt":32811
# 2  distractorQ2":"81.23   rt":36309
# 2  distractorQ2":"78.87   rt":31562
# 2  distractorQ2":"24.22   rt":33213
# 2  distractorQ2":"73.34   rt":48216
# 2  distractorQ2":"47.78   rt":20487
# 2  distractorQ2":"25.52   rt":35848
# 2  distractorQ2":"29.05   rt":24513
# 2  distractorQ2":"45.89   rt":30552
# 2  distractorQ2":"36.71   rt":38732
# 3  distractorQ2":"99.12   rt":40129
# 3  distractorQ2":"86.56   rt":41483
# 3  distractorQ2":"92.59   rt":38136
# 3  distractorQ2":"89.20   rt":37118
# 3  distractorQ2":"43.22   rt":40907
# 3  distractorQ2":"35.30   rt":31702
# 3  distractorQ2":"86.81   rt":35856
# 3  distractorQ2":"21.48   rt":34268
# 3  distractorQ2":"68.72   rt":32509
# 3  distractorQ2":"94.85   rt":27488
# 4  distractorQ2":"49.05   rt":28762
# 4  distractorQ2":"24.80   rt":82448
# 4  distractorQ2":"48.53   rt":59912
# 4  distractorQ2":"20.74  rt":133357
# 4  distractorQ2":"71.63   rt":48966
# 4  distractorQ2":"50.19   rt":24397
# 4  distractorQ2":"88.07   rt":42346
# 4  distractorQ2":"48.32   rt":30586
# 4  distractorQ2":"80.14   rt":44242
# 4  distractorQ2":"24.80   rt":35531

# %%
ratings = ratings[["id",0,1,2,5,6,7,8,9]]
ratings = ratings.rename(columns={0:"story",1:"condition",2:"experiment",5:"predictable",6:"unpredictable",7:"script",8:"interaction",9:"rt"})
ratings = ratings.replace({'"story":"':'','prag_condition":"':'','experiment":"':'','redundantQ":"':'','informativeQ":"':'','distractorQ1":"':'','distractorQ2":"':'','rt":':'','^a_':'','^b_':'','^c_':'','^d_':'','^e_':'','^f_':'','^informative':'wonky','biased':'wonky','informative$':'unpredictable','redundant$':'predictable','1_filler':'filler1','2_filler':'filler2','3_filler':'filler3','4_filler':'filler4'}, regex=True)
ratings["trial"] = list(range(1,11))*int(len(ratings.index)/10)
ratings['world'], ratings['activity'] = ratings['condition'].str.split('_', 1).str


ratings = pn.melt(ratings, id_vars=['id', 'trial','story','world','activity','experiment','rt'], value_vars=['predictable', 'unpredictable','script','interaction'])
ratings
# Out:
#                  id  trial         story    world       activity   experiment  \
# 0    A3F2J0WFJKEHQ6      1    23_library  filler3            NaN       period
# 1    A3F2J0WFJKEHQ6      2       18_hair  typical    predictable       period
# 2    A3F2J0WFJKEHQ6      3  2_restaurant    wonky    predictable      control
# 3    A3F2J0WFJKEHQ6      4   17_airplane  filler2            NaN       ohyeah
# 4    A3F2J0WFJKEHQ6      5     1_grocery    wonky  unpredictable       ohyeah
# 5    A3F2J0WFJKEHQ6      6        13_bus    wonky            NaN  exclamation
# 6    A3F2J0WFJKEHQ6      7        8_work  typical            NaN  exclamation
# 7    A3F2J0WFJKEHQ6      8       7_train  typical  unpredictable  exclamation
# 8    A3F2J0WFJKEHQ6      9      4_subway  filler1            NaN  exclamation
# 9    A3F2J0WFJKEHQ6     10     5_fueling  filler4            NaN  exclamation
# 10    ATF7HBD1TFI2U      1      20_drive  typical            NaN  exclamation
# 11    ATF7HBD1TFI2U      2   17_airplane  filler2            NaN  exclamation
# 12    ATF7HBD1TFI2U      3    3_feed_dog    wonky  unpredictable  exclamation
# 13    ATF7HBD1TFI2U      4     12_letter  filler4            NaN       period
# 14    ATF7HBD1TFI2U      5       7_train    wonky    predictable       period
# 15    ATF7HBD1TFI2U      6      9_doctor  filler3            NaN      control
# 16    ATF7HBD1TFI2U      7    6_swimming  typical  unpredictable      control
# 17    ATF7HBD1TFI2U      8    10_shampoo    wonky            NaN       ohyeah
# 18    ATF7HBD1TFI2U      9     5_fueling  filler1            NaN       ohyeah
# 19    ATF7HBD1TFI2U     10     22_dishes  typical    predictable       ohyeah
# 20   A1JN13098RIE78      1     1_grocery  filler2            NaN  exclamation
# 21   A1JN13098RIE78      2    10_shampoo  filler4            NaN  exclamation
# 22   A1JN13098RIE78      3    3_feed_dog    wonky  unpredictable  exclamation
# 23   A1JN13098RIE78      4     12_letter  filler1            NaN      control
# 24   A1JN13098RIE78      5  11_skydiving  typical  unpredictable      control
# 25   A1JN13098RIE78      6    23_library  typical            NaN       period
# 26   A1JN13098RIE78      7      9_doctor  filler3            NaN       period
# 27   A1JN13098RIE78      8       18_hair    wonky    predictable       period
# 28   A1JN13098RIE78      9     5_fueling    wonky            NaN       ohyeah
# 29   A1JN13098RIE78     10  2_restaurant  typical    predictable       ohyeah
# ..              ...    ...           ...      ...            ...          ...
# 170  A1JN13098RIE78      1     1_grocery  filler2            NaN  exclamation
# 171  A1JN13098RIE78      2    10_shampoo  filler4            NaN  exclamation
# 172  A1JN13098RIE78      3    3_feed_dog    wonky  unpredictable  exclamation
# 173  A1JN13098RIE78      4     12_letter  filler1            NaN      control
# 174  A1JN13098RIE78      5  11_skydiving  typical  unpredictable      control
# 175  A1JN13098RIE78      6    23_library  typical            NaN       period
# 176  A1JN13098RIE78      7      9_doctor  filler3            NaN       period
# 177  A1JN13098RIE78      8       18_hair    wonky    predictable       period
# 178  A1JN13098RIE78      9     5_fueling    wonky            NaN       ohyeah
# 179  A1JN13098RIE78     10  2_restaurant  typical    predictable       ohyeah
# 180  A29ANBEU3JKCKZ      1    3_feed_dog  filler4            NaN       period
# 181  A29ANBEU3JKCKZ      2      4_subway  typical    predictable       period
# 182  A29ANBEU3JKCKZ      3     22_dishes  filler1            NaN  exclamation
# 183  A29ANBEU3JKCKZ      4      20_drive  typical            NaN  exclamation
# 184  A29ANBEU3JKCKZ      5        13_bus  filler3            NaN  exclamation
# 185  A29ANBEU3JKCKZ      6    23_library  typical  unpredictable  exclamation
# 186  A29ANBEU3JKCKZ      7   17_airplane  filler2            NaN      control
# 187  A29ANBEU3JKCKZ      8    19_exhibit    wonky  unpredictable      control
# 188  A29ANBEU3JKCKZ      9       18_hair    wonky    predictable       ohyeah
# 189  A29ANBEU3JKCKZ     10    24_laundry    wonky            NaN       ohyeah
# 190  A1RVMADIZE3BXK      1      21_pizza  typical  unpredictable      control
# 191  A1RVMADIZE3BXK      2        13_bus    wonky            NaN       ohyeah
# 192  A1RVMADIZE3BXK      3     12_letter    wonky    predictable       ohyeah
# 193  A1RVMADIZE3BXK      4   17_airplane    wonky  unpredictable       period
# 194  A1RVMADIZE3BXK      5    10_shampoo  typical            NaN  exclamation
# 195  A1RVMADIZE3BXK      6    19_exhibit  filler4            NaN  exclamation
# 196  A1RVMADIZE3BXK      7    6_swimming  filler3            NaN  exclamation
# 197  A1RVMADIZE3BXK      8      9_doctor  typical    predictable  exclamation
# 198  A1RVMADIZE3BXK      9     1_grocery  filler2            NaN  exclamation
# 199  A1RVMADIZE3BXK     10    14_clothes  filler1            NaN  exclamation
#
#          rt     variable  value
# 0     37905  predictable   4.47
# 1     25457  predictable  92.69
# 2     32099  predictable  48.74
# 3     37324  predictable  85.89
# 4     36312  predictable  17.40
# 5     24275  predictable   1.61
# 6     31269  predictable  53.00
# 7     34153  predictable  98.01
# 8     36620  predictable  88.10
# 9     25200  predictable  50.22
# 10    43945  predictable  94.27
# 11    52525  predictable  99.36
# 12    78907  predictable  98.74
# 13    52239  predictable   8.55
# 14    48564  predictable  86.32
# 15    57433  predictable   9.92
# 16    52478  predictable  98.61
# 17    53440  predictable   0.48
# 18    36991  predictable  98.99
# 19    44289  predictable  83.83
# 20    32811  predictable  99.13
# 21    36309  predictable   1.84
# 22    31562  predictable  98.31
# 23    33213  predictable  90.18
# 24    48216  predictable  80.52
# 25    20487  predictable  98.07
# 26    35848  predictable  10.09
# 27    24513  predictable  17.15
# 28    30552  predictable  73.22
# 29    38732  predictable  57.79
# ..      ...          ...    ...
# 170   32811  interaction  72.04
# 171   36309  interaction  81.23
# 172   31562  interaction  78.87
# 173   33213  interaction  24.22
# 174   48216  interaction  73.34
# 175   20487  interaction  47.78
# 176   35848  interaction  25.52
# 177   24513  interaction  29.05
# 178   30552  interaction  45.89
# 179   38732  interaction  36.71
# 180   40129  interaction  99.12
# 181   41483  interaction  86.56
# 182   38136  interaction  92.59
# 183   37118  interaction  89.20
# 184   40907  interaction  43.22
# 185   31702  interaction  35.30
# 186   35856  interaction  86.81
# 187   34268  interaction  21.48
# 188   32509  interaction  68.72
# 189   27488  interaction  94.85
# 190   28762  interaction  49.05
# 191   82448  interaction  24.80
# 192   59912  interaction  48.53
# 193  133357  interaction  20.74
# 194   48966  interaction  71.63
# 195   24397  interaction  50.19
# 196   42346  interaction  88.07
# 197   30586  interaction  48.32
# 198   44242  interaction  80.14
# 199   35531  interaction  24.80
#
# [200 rows x 9 columns]

# %%
ratings['condition'] = np.where(ratings['activity'].isin(['predictable', 'unpredictable']), 'after', 'before')
ratings
# Out:
#                  id  trial         story    world       activity   experiment  \
# 0    A3F2J0WFJKEHQ6      1    23_library  filler3            NaN       period
# 1    A3F2J0WFJKEHQ6      2       18_hair  typical    predictable       period
# 2    A3F2J0WFJKEHQ6      3  2_restaurant    wonky    predictable      control
# 3    A3F2J0WFJKEHQ6      4   17_airplane  filler2            NaN       ohyeah
# 4    A3F2J0WFJKEHQ6      5     1_grocery    wonky  unpredictable       ohyeah
# 5    A3F2J0WFJKEHQ6      6        13_bus    wonky            NaN  exclamation
# 6    A3F2J0WFJKEHQ6      7        8_work  typical            NaN  exclamation
# 7    A3F2J0WFJKEHQ6      8       7_train  typical  unpredictable  exclamation
# 8    A3F2J0WFJKEHQ6      9      4_subway  filler1            NaN  exclamation
# 9    A3F2J0WFJKEHQ6     10     5_fueling  filler4            NaN  exclamation
# 10    ATF7HBD1TFI2U      1      20_drive  typical            NaN  exclamation
# 11    ATF7HBD1TFI2U      2   17_airplane  filler2            NaN  exclamation
# 12    ATF7HBD1TFI2U      3    3_feed_dog    wonky  unpredictable  exclamation
# 13    ATF7HBD1TFI2U      4     12_letter  filler4            NaN       period
# 14    ATF7HBD1TFI2U      5       7_train    wonky    predictable       period
# 15    ATF7HBD1TFI2U      6      9_doctor  filler3            NaN      control
# 16    ATF7HBD1TFI2U      7    6_swimming  typical  unpredictable      control
# 17    ATF7HBD1TFI2U      8    10_shampoo    wonky            NaN       ohyeah
# 18    ATF7HBD1TFI2U      9     5_fueling  filler1            NaN       ohyeah
# 19    ATF7HBD1TFI2U     10     22_dishes  typical    predictable       ohyeah
# 20   A1JN13098RIE78      1     1_grocery  filler2            NaN  exclamation
# 21   A1JN13098RIE78      2    10_shampoo  filler4            NaN  exclamation
# 22   A1JN13098RIE78      3    3_feed_dog    wonky  unpredictable  exclamation
# 23   A1JN13098RIE78      4     12_letter  filler1            NaN      control
# 24   A1JN13098RIE78      5  11_skydiving  typical  unpredictable      control
# 25   A1JN13098RIE78      6    23_library  typical            NaN       period
# 26   A1JN13098RIE78      7      9_doctor  filler3            NaN       period
# 27   A1JN13098RIE78      8       18_hair    wonky    predictable       period
# 28   A1JN13098RIE78      9     5_fueling    wonky            NaN       ohyeah
# 29   A1JN13098RIE78     10  2_restaurant  typical    predictable       ohyeah
# ..              ...    ...           ...      ...            ...          ...
# 170  A1JN13098RIE78      1     1_grocery  filler2            NaN  exclamation
# 171  A1JN13098RIE78      2    10_shampoo  filler4            NaN  exclamation
# 172  A1JN13098RIE78      3    3_feed_dog    wonky  unpredictable  exclamation
# 173  A1JN13098RIE78      4     12_letter  filler1            NaN      control
# 174  A1JN13098RIE78      5  11_skydiving  typical  unpredictable      control
# 175  A1JN13098RIE78      6    23_library  typical            NaN       period
# 176  A1JN13098RIE78      7      9_doctor  filler3            NaN       period
# 177  A1JN13098RIE78      8       18_hair    wonky    predictable       period
# 178  A1JN13098RIE78      9     5_fueling    wonky            NaN       ohyeah
# 179  A1JN13098RIE78     10  2_restaurant  typical    predictable       ohyeah
# 180  A29ANBEU3JKCKZ      1    3_feed_dog  filler4            NaN       period
# 181  A29ANBEU3JKCKZ      2      4_subway  typical    predictable       period
# 182  A29ANBEU3JKCKZ      3     22_dishes  filler1            NaN  exclamation
# 183  A29ANBEU3JKCKZ      4      20_drive  typical            NaN  exclamation
# 184  A29ANBEU3JKCKZ      5        13_bus  filler3            NaN  exclamation
# 185  A29ANBEU3JKCKZ      6    23_library  typical  unpredictable  exclamation
# 186  A29ANBEU3JKCKZ      7   17_airplane  filler2            NaN      control
# 187  A29ANBEU3JKCKZ      8    19_exhibit    wonky  unpredictable      control
# 188  A29ANBEU3JKCKZ      9       18_hair    wonky    predictable       ohyeah
# 189  A29ANBEU3JKCKZ     10    24_laundry    wonky            NaN       ohyeah
# 190  A1RVMADIZE3BXK      1      21_pizza  typical  unpredictable      control
# 191  A1RVMADIZE3BXK      2        13_bus    wonky            NaN       ohyeah
# 192  A1RVMADIZE3BXK      3     12_letter    wonky    predictable       ohyeah
# 193  A1RVMADIZE3BXK      4   17_airplane    wonky  unpredictable       period
# 194  A1RVMADIZE3BXK      5    10_shampoo  typical            NaN  exclamation
# 195  A1RVMADIZE3BXK      6    19_exhibit  filler4            NaN  exclamation
# 196  A1RVMADIZE3BXK      7    6_swimming  filler3            NaN  exclamation
# 197  A1RVMADIZE3BXK      8      9_doctor  typical    predictable  exclamation
# 198  A1RVMADIZE3BXK      9     1_grocery  filler2            NaN  exclamation
# 199  A1RVMADIZE3BXK     10    14_clothes  filler1            NaN  exclamation
#
#          rt     variable  value condition
# 0     37905  predictable   4.47    before
# 1     25457  predictable  92.69     after
# 2     32099  predictable  48.74     after
# 3     37324  predictable  85.89    before
# 4     36312  predictable  17.40     after
# 5     24275  predictable   1.61    before
# 6     31269  predictable  53.00    before
# 7     34153  predictable  98.01     after
# 8     36620  predictable  88.10    before
# 9     25200  predictable  50.22    before
# 10    43945  predictable  94.27    before
# 11    52525  predictable  99.36    before
# 12    78907  predictable  98.74     after
# 13    52239  predictable   8.55    before
# 14    48564  predictable  86.32     after
# 15    57433  predictable   9.92    before
# 16    52478  predictable  98.61     after
# 17    53440  predictable   0.48    before
# 18    36991  predictable  98.99    before
# 19    44289  predictable  83.83     after
# 20    32811  predictable  99.13    before
# 21    36309  predictable   1.84    before
# 22    31562  predictable  98.31     after
# 23    33213  predictable  90.18    before
# 24    48216  predictable  80.52     after
# 25    20487  predictable  98.07    before
# 26    35848  predictable  10.09    before
# 27    24513  predictable  17.15     after
# 28    30552  predictable  73.22    before
# 29    38732  predictable  57.79     after
# ..      ...          ...    ...       ...
# 170   32811  interaction  72.04    before
# 171   36309  interaction  81.23    before
# 172   31562  interaction  78.87     after
# 173   33213  interaction  24.22    before
# 174   48216  interaction  73.34     after
# 175   20487  interaction  47.78    before
# 176   35848  interaction  25.52    before
# 177   24513  interaction  29.05     after
# 178   30552  interaction  45.89    before
# 179   38732  interaction  36.71     after
# 180   40129  interaction  99.12    before
# 181   41483  interaction  86.56     after
# 182   38136  interaction  92.59    before
# 183   37118  interaction  89.20    before
# 184   40907  interaction  43.22    before
# 185   31702  interaction  35.30     after
# 186   35856  interaction  86.81    before
# 187   34268  interaction  21.48     after
# 188   32509  interaction  68.72     after
# 189   27488  interaction  94.85    before
# 190   28762  interaction  49.05     after
# 191   82448  interaction  24.80    before
# 192   59912  interaction  48.53     after
# 193  133357  interaction  20.74     after
# 194   48966  interaction  71.63    before
# 195   24397  interaction  50.19    before
# 196   42346  interaction  88.07    before
# 197   30586  interaction  48.32     after
# 198   44242  interaction  80.14    before
# 199   35531  interaction  24.80    before
#
# [200 rows x 10 columns]

# %%
z = data["demographics"].str.split('},').apply(pn.Series, 1).stack()
z.index = z.index.droplevel(-1)
z.name = "demographics"
z
# Out:
# 0    "gender":"male","age":"55","language":"English...
# 1    "gender":"female","age":"45","language":"engli...
# 2    "gender":"female","age":"55","language":"Engli...
# 3    "gender":"female","age":"25","language":"Engli...
# 4    "gender":"female","age":"35","language":"Engli...
# Name: demographics, dtype: object

# %%
demographics = data[["id","time"]]

demographics = demographics.join(z.apply(lambda x: pn.Series(x.split('","'))))

demographics
# Out:
#                id  time                 0         1                   2  \
# 0  A3F2J0WFJKEHQ6   433    "gender":"male  age":"55  language":"English
# 1   ATF7HBD1TFI2U   743  "gender":"female  age":"45  language":"english
# 2  A1JN13098RIE78   902  "gender":"female  age":"55  language":"English
# 3  A29ANBEU3JKCKZ   565  "gender":"female  age":"25  language":"English
# 4  A1RVMADIZE3BXK  1233  "gender":"female  age":"35  language":"English
#
#                        3                                                  4
# 0            comments":"                                  about":"No idea"}
# 1            comments":"                             about":"i don't know"}
# 2            comments":"                  about":"Inferring from stories?"}
# 3            comments":"  about":"To measure how people perceive certain...
# 4  comments":"Thank you!                     about":"I'm really not sure."}

# %%
demographics = demographics[["id",0,1,2,3,4]]
demographics = demographics.rename(columns={0:"gender",1:"age",2:"language",3:"comments",4:"thoughts"})
demographics = demographics.replace({'"gender":"':'','^age":"':'','language":"':'','comments":"':'','about":"':'','"}':''}, regex=True)

demographics
# Out:
#                id  gender age language    comments  \
# 0  A3F2J0WFJKEHQ6    male  55  English
# 1   ATF7HBD1TFI2U  female  45  english
# 2  A1JN13098RIE78  female  55  English
# 3  A29ANBEU3JKCKZ  female  25  English
# 4  A1RVMADIZE3BXK  female  35  English  Thank you!
#
#                                             thoughts
# 0                                            No idea
# 1                                       i don't know
# 2                            Inferring from stories?
# 3  To measure how people perceive certain scenarios.
# 4                               I'm really not sure.

# %%
ratings.to_csv("/Users/ekravtch/Shared/informationally-redundant-utterances/data/MTurk/processed_fillers.csv", index=False)

# %%
demographics.to_csv("/Users/ekravtch/Shared/informationally-redundant-utterances/data/MTurk/processed_fillers_demographics.csv", index=False)
